# %%
import torch
import sys
nonlinearities=False
gets_spectral_input=False
sta_enabled=False
batch_size=128
n_epochs=5000
lr=0.01

# %% [markdown]
# # Create models

# %%
from Models import Encoder
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
enc = Encoder(nonlinearities=nonlinearities, gets_spectral_input=gets_spectral_input, sta_enabled=sta_enabled)
enc = enc.to(device)

# %%
len(list(enc.parameters()))

# %%
from Train_sta import train
from Utils import SignalsDataset
from torch.utils.data import DataLoader
from torch.optim import SGD
from torch.optim import Adam

ds_train = SignalsDataset('train_data_signal__sinX__amp_2__freq_2__noise_uniform__low_-1__high_1.npz')
dl_train = DataLoader(ds_train, batch_size=batch_size, shuffle=True, drop_last=True)
ds_val = SignalsDataset('val_data_signal__sinX__amp_2__freq_2__noise_uniform__low_-1__high_1.npz')
dl_val = DataLoader(ds_val, batch_size=batch_size, shuffle=True, drop_last=True)
ds_test = SignalsDataset('test_data_signal__sinX__amp_2__freq_2__noise_uniform__low_-1__high_1.npz')
dl_test = DataLoader(ds_test, batch_size=batch_size, shuffle=True, drop_last=True)
optimizer = SGD(enc.parameters(), lr=lr)
loss_func = torch.nn.MSELoss()

train(enc, 'linear_with_relu', dl_train, dl_val, dl_test, n_epochs, optimizer, loss_func, print_every=1, checkpoint_every=50, with_freq=gets_spectral_input)

# %% [markdown]
# from Train_sta import train
# from Utils import SignalsDataset
# from torch.utils.data import DataLoader
# from torch.optim import SGD
# from torch.optim import Adam
#
# ds_train = SignalsDataset('train_data_signal__sinX__amp_2__freq_2__noise_uniform__low_-1__high_1.npz')
# dl_train = DataLoader(ds_train, batch_size=batch_size, shuffle=True, drop_last=True)
# ds_val = SignalsDataset('val_data_signal__sinX__amp_2__freq_2__noise_uniform__low_-1__high_1.npz')
# dl_val = DataLoader(ds_val, batch_size=batch_size, shuffle=True, drop_last=True)
# ds_test = SignalsDataset('test_data_signal__sinX__amp_2__freq_2__noise_uniform__low_-1__high_1.npz')
# dl_test = DataLoader(ds_test, batch_size=batch_size, shuffle=True, drop_last=True)
# optimizer = SGD(enc.parameters(), lr=lr)
# loss_func = torch.nn.MSELoss()
#
# train(enc, 'linear_with_relu', dl_train, dl_val, dl_test, n_epochs, optimizer, loss_func, print_every=1, checkpoint_every=50, with_freq=gets_spectral_input)

# %%
from Models import Encoder
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
enc = Encoder(nonlinearities=nonlinearities, gets_spectral_input=gets_spectral_input, sta_enabled=sta_enabled)
enc = enc.to(device)

# %%
len(list(enc.parameters()))
# Out:
# 4

# %%
from Train_sta import train
from Utils import SignalsDataset
from torch.utils.data import DataLoader
from torch.optim import SGD
from torch.optim import Adam

ds_train = SignalsDataset('train_data_signal__sinX__amp_2__freq_2__noise_uniform__low_-1__high_1.npz')
dl_train = DataLoader(ds_train, batch_size=batch_size, shuffle=True, drop_last=True)
ds_val = SignalsDataset('val_data_signal__sinX__amp_2__freq_2__noise_uniform__low_-1__high_1.npz')
dl_val = DataLoader(ds_val, batch_size=batch_size, shuffle=True, drop_last=True)
ds_test = SignalsDataset('test_data_signal__sinX__amp_2__freq_2__noise_uniform__low_-1__high_1.npz')
dl_test = DataLoader(ds_test, batch_size=batch_size, shuffle=True, drop_last=True)
optimizer = SGD(enc.parameters(), lr=lr)
loss_func = torch.nn.MSELoss()

train(enc, 'linear_with_relu', dl_train, dl_val, dl_test, n_epochs, optimizer, loss_func, print_every=1, checkpoint_every=50, with_freq=gets_spectral_input)
# Out:
# Start epoch 1
# ...
# Epoch: 1 | Train Loss: 0.0374 | Val loss: 0.037 |
# Start epoch 2
# ...
# Epoch: 2 | Train Loss: 0.0368 | Val loss: 0.036 |
# Start epoch 3
# ...
# Epoch: 3 | Train Loss: 0.0362 | Val loss: 0.036 |
# Start epoch 4
# ...
# Epoch: 4 | Train Loss: 0.0356 | Val loss: 0.035 |
# Start epoch 5
# ...
# Epoch: 5 | Train Loss: 0.0350 | Val loss: 0.035 |
# Start epoch 6
# ...
# Epoch: 6 | Train Loss: 0.0345 | Val loss: 0.034 |
# Start epoch 7
# ...
# Epoch: 7 | Train Loss: 0.0340 | Val loss: 0.034 |
# Start epoch 8
# ...
# Epoch: 8 | Train Loss: 0.0334 | Val loss: 0.033 |
# Start epoch 9
# ...
# Epoch: 9 | Train Loss: 0.0329 | Val loss: 0.033 |
# Start epoch 10
# ...
# Epoch: 10 | Train Loss: 0.0324 | Val loss: 0.032 |
# Start epoch 11
# ...
# Epoch: 11 | Train Loss: 0.0319 | Val loss: 0.032 |
# Start epoch 12
# ...
# Epoch: 12 | Train Loss: 0.0315 | Val loss: 0.031 |
# Start epoch 13
# ...
# Epoch: 13 | Train Loss: 0.0310 | Val loss: 0.031 |
# Start epoch 14
# ...
# Epoch: 14 | Train Loss: 0.0306 | Val loss: 0.030 |
# Start epoch 15
# ...
